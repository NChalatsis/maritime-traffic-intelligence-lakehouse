# %%
# Bronze validation notebook for checking table load, schema, and sample records

# %%
display(spark.table("bronze_ais_synthetic").limit(20))

# %%
spark.table("bronze_ais_synthetic").printSchema()
